# %% [markdown]
# ## Notebook Description

# %% [markdown]
# **Process**:
#
# 1. Get 200 articles from the DB
# 2. Perform clustering analysis on these articles to identify those that are similar
# 3. Manually look at these clusters to identify common traits that we can use for tagging
#
# IDEAS:
#
# - Keyword tagging? Might be computationally expensive but could let it run in the background while doing other things
# - Do we want to use a predefined set of tags or simply group similar articles?

# %% [markdown]
# ## Imports

# %%
# For data importing and preprocessing
import pandas as pd
import json

# For clustering
from sklearn.cluster import KMeans      # KNN clustering (k means clustering)
from data_analysis.ClusteringTechniques import *

# For NER 
import spacy    # "pip install spacy" AND "python -m spacy download en_core_web_sm"

# For Rule Based Tagging
import re


# Custom classes
from FP_Classes.RSS_Feed import RSS_Article
from FP_Classes.RSS_DB_Connection import RSS_DB_Connection

# %%
from data_analysis.ClusteringTechniques import *
from FP_Classes.RSS_DB_Connection import RSS_DB_Connection
import json 
import re 

from FP_Classes.RSS_Feed import RSS_Feed, RSS_Article
from FP_Classes.Tag import Tag
from FP_Classes.Feeds.BleepingComputer import BleepingComputerRSS   # BleepingComputer
from FP_Classes.Feeds.Censys import CensysRSS                       # Censys (general)
from FP_Classes.Feeds.CensysDir import CensysDirRSS                 # Censys (director)
from FP_Classes.Feeds.DefenseDepartment import DefenseDeptRSS       # Department of Defense
from FP_Classes.Feeds.Microsoft import MicrosoftRSS                 # Microsoft 
from FP_Classes.Feeds.NationalVulnDatabase import NVD_RSS           # National Vulnerability Database
from FP_Classes.Feeds.NIST import NIST_RSS                          # NIST 
from FP_Classes.Feeds.StateDepartment import StateDeptRSS           # State Department (multiple feeds) - NOTE: This one takes a very long time so I removed it for now
from FP_Classes.Feeds.TheHackerNews import HackerNewsRSS            # Hacker News (news articles)


config = json.load(open('config/config.json'))
db_creds = json.load(open('config/' + config['db-creds-json-path']))

dbConn:RSS_DB_Connection = RSS_DB_Connection(
                                username=db_creds['username'],
                                password=db_creds['password'],
                                host=db_creds['host']
                            )

# Initialization of all variables
configDir = "config/"                                   # Change if you changed the default file hierarchy 

# Update the remote DB with new tags if there are any
if dbConn.newTagsFromExcel(configDir + config['update-tags-filepath']):
    print("[+] NOTICE: Added new tags to remote database.")
else: 
    print("[+] ERROR: Failed to add new tags to the remote database. Moving on.")

# Initialize all Feed objects 
bleepingComputerRss = BleepingComputerRSS()
#censysRss = CensysRSS()
#censysDirRss = CensysDirRSS()
defenseDeptRss = DefenseDeptRSS()
microsoftRss = MicrosoftRSS()
nvdRss = NVD_RSS()
nistRss = NIST_RSS()
#stateDeptRss = StateDeptRSS()      # Intentionally commented out - see above import statement
hackernewsRss = HackerNewsRSS()

# Create a list of all the RSS Feed objects 
allFeeds:list[RSS_Feed] = [
    bleepingComputerRss,
    #censysRss,
    #censysDirRss,
    defenseDeptRss,
    microsoftRss,
    nvdRss,
    nistRss,
    #stateDeptRss,  # Intentionally commented out - see above import statement
    hackernewsRss
]

allTags:list[Tag] = dbConn.getAllTags()
# Out:
# NOTICE in RSS_DB_Connection.newTagsFromExcel(): called newTagsFromExcel() - beginning process.
# NOTICE in RSS_DB_Connection.newTagsFromExcel(): excel sheet read and DB connection established successfully. Formatting query...
# NOTICE in RSS_DB_Connection.newTagsFromExcel(): new tag queries formatted and executed successfully. Terminating connections and quitting.
# SUCCESS.
# [+] NOTICE: Added new tags to remote database.
# [+] Initializing feed: BleepingComputer | https://www.bleepingcomputer.com/feed/
# [+] INIT article "BleepingComputer - Amazon's AWS SSM agent can be used as post-exploitation RAT malware"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Why Every Security Practitioner Should Attend mWISE"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Hackers exploited Salesforce zero-day in Facebook phishing attack"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Hackers use new malware to breach air-gapped devices in Eastern Europe"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Threat actors abuse Google AMP for evasive phishing attacks"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - CISA issues new warning on actively exploited Ivanti MobileIron bugs"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Retail chain Hot Topic discloses wave of credential-stuffing attacks"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Cybercriminals train AI chatbots for phishing, malware attacks"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - How to manage a mass password reset due to a ransomware attack"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Hackers steal Signal, WhatsApp user data with fake Android chat app"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Google warns again it will start deleting inactive accounts in December"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Canon warns of Wi-Fi security risks when discarding inkjet printers"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] Initializing feed: Defense-gov Explore Feed | https://www.defense.gov/news/rss/
# 	Getting articles for link 1/3 | https://www.defense.gov/DesktopModules/ArticleCS/RSS.ashx?ContentType=2&Site=945&max=10
# 		Found 10 articles.
# 			Article: On-Camera Press Briefing
# [+] INIT article "Defense-gov Explore Feed - On-Camera Press Briefing"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Joint U.S. - Australia Press Conference Tonight, 12:10 a.m. EDT
# [+] INIT article "Defense-gov Explore Feed - Joint U.S. - Australia Press Conference Tonight, 12:10 a.m. EDT"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Secretary of Defense Lloyd J. Austin III, Papua New Guinea Prime Minister James Marape Press Briefing Today at 9:00 p.m.
# [+] INIT article "Defense-gov Explore Feed - Secretary of Defense Lloyd J. Austin III, Papua New Guinea Prime Minister James Marape Press Briefing Today at 9:00 p.m."
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Pentagon Commemorates 75th Anniversary of Desegregation in the Federal Workforce and Armed Forces
# [+] INIT article "Defense-gov Explore Feed - Pentagon Commemorates 75th Anniversary of Desegregation in the Federal Workforce and Armed Forces"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: On-Camera Press Briefing
# [+] INIT article "Defense-gov Explore Feed - On-Camera Press Briefing"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Secretary of Defense Travel to Papua New Guinea, Australia
# [+] INIT article "Defense-gov Explore Feed - Secretary of Defense Travel to Papua New Guinea, Australia"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Secretary of Defense Austin and Chairman of the Joint Chiefs of Staff Gen. Milley Press Conference Today at 12:30 p.m.
# [+] INIT article "Defense-gov Explore Feed - Secretary of Defense Austin and Chairman of the Joint Chiefs of Staff Gen. Milley Press Conference Today at 12:30 p.m."
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Department of Defense Media Invitation Announced for Appellate Oral Argument in the Case of Adb Al Rahim Hussayn Muhammad Al-Nashiri
# [+] INIT article "Defense-gov Explore Feed - Department of Defense Media Invitation Announced for Appellate Oral Argument in the Case of Adb Al Rahim Hussayn Muhammad Al-Nashiri"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: On-Camera Press Briefing
# [+] INIT article "Defense-gov Explore Feed - On-Camera Press Briefing"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Secretary of Defense to Administer Oath of Enlistment at Baltimore Military Entrance Processing Station
# [+] INIT article "Defense-gov Explore Feed - Secretary of Defense to Administer Oath of Enlistment at Baltimore Military Entrance Processing Station"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 	Getting articles for link 2/3 | https://www.defense.gov/DesktopModules/ArticleCS/RSS.ashx?ContentType=9&Site=945&max=10
# 		Found 10 articles.
# 			Article: Secretary of Defense Lloyd J. Austin III's Call with Mozambican President Filipe Jacinto Nyusi
# [+] INIT article "Defense-gov Explore Feed - Secretary of Defense Lloyd J. Austin III's Call with Mozambican President Filipe Jacinto Nyusi"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Statement From Pentagon Press Secretary Brig. Gen. Patrick Ryder on U.S. Space Command
# [+] INIT article "Defense-gov Explore Feed - Statement From Pentagon Press Secretary Brig. Gen. Patrick Ryder on U.S. Space Command"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Defense Department Updates Its Law of War Manual
# [+] INIT article "Defense-gov Explore Feed - Defense Department Updates Its Law of War Manual"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Statement by Secretary of Defense Lloyd J. Austin III on the Upcoming Departure of Under Secretary of Defense for Personnel and Readiness Gilbert R. Cisneros, Jr.
# [+] INIT article "Defense-gov Explore Feed - Statement by Secretary of Defense Lloyd J. Austin III on the Upcoming Departure of Under Secretary of Defense for Personnel and Readiness Gilbert R. Cisneros, Jr."
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Readout of Under Secretary of Defense for Acquisition and Sustainment, Dr. William LaPlante, and the Republic of Korea's Minister of Defense, Acquisition Program Administration, Mr. Eom Dong-hwan, Co-Chairing of the 48th Annual Defense Technological and Industrial Cooperation Committee
# [+] INIT article "Defense-gov Explore Feed - Readout of Under Secretary of Defense for Acquisition and Sustainment, Dr. William LaPlante, and the Republic of Korea's Minister of Defense, Acquisition Program Administration, Mr. Eom Dong-hwan, Co-Chairing of the 48th Annual Defense Technological and Industrial Cooperation Committee"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Joint Statement on Australia-U.S. Ministerial Consultations (AUSMIN) 2023
# [+] INIT article "Defense-gov Explore Feed - Joint Statement on Australia-U.S. Ministerial Consultations (AUSMIN) 2023"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Fact Sheet: 2023 Australia – U.S. Ministerial Consultations (AUSMIN)
# [+] INIT article "Defense-gov Explore Feed - Fact Sheet: 2023 Australia – U.S. Ministerial Consultations (AUSMIN)"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Navy to Christen Guided-Missile Destroyer Harvey C. Barnum Jr. (DDG 124)
# [+] INIT article "Defense-gov Explore Feed - Navy to Christen Guided-Missile Destroyer Harvey C. Barnum Jr. (DDG 124)"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Flag Officer Announcements
# [+] INIT article "Defense-gov Explore Feed - Flag Officer Announcements"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: General Officer Announcement
# [+] INIT article "Defense-gov Explore Feed - General Officer Announcement"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 	Getting articles for link 3/3 | https://www.defense.gov/DesktopModules/ArticleCS/RSS.ashx?ContentType=800&Site=945&max=10
# 		Found 10 articles.
# 			Article: Face of Defense: From Trombones and Marathons to Combat Camera
# [+] INIT article "Defense-gov Explore Feed - Face of Defense: From Trombones and Marathons to Combat Camera"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Ryan Strong: A Pediatric Cancer Patient's Remarkable Recovery Journey
# [+] INIT article "Defense-gov Explore Feed - Ryan Strong: A Pediatric Cancer Patient's Remarkable Recovery Journey"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Medal of Honor Monday: Marine Corps Pvt. Joseph Ozbourn
# [+] INIT article "Defense-gov Explore Feed - Medal of Honor Monday: Marine Corps Pvt. Joseph Ozbourn"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Troops, Locals Forge Friendship During Talisman Sabre
# [+] INIT article "Defense-gov Explore Feed - Troops, Locals Forge Friendship During Talisman Sabre"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Marine Corps Sergeant Deploys Again to Australia
# [+] INIT article "Defense-gov Explore Feed - Marine Corps Sergeant Deploys Again to Australia"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Firefighter Who Loves Challenges Enlists in the Marine Corps
# [+] INIT article "Defense-gov Explore Feed - Firefighter Who Loves Challenges Enlists in the Marine Corps"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Haitian Teen Learns English, Then Joins Marine Corps
# [+] INIT article "Defense-gov Explore Feed - Haitian Teen Learns English, Then Joins Marine Corps"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: Warship's Crew Brings 'Can Do' Attitude
# [+] INIT article "Defense-gov Explore Feed - Warship's Crew Brings 'Can Do' Attitude"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: NFL Player Trains With Troops, Hold Clinics for Military Kids in Japan
# [+] INIT article "Defense-gov Explore Feed - NFL Player Trains With Troops, Hold Clinics for Military Kids in Japan"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 			Article: The Journey to Becoming an Air Force Cadet
# [+] INIT article "Defense-gov Explore Feed - The Journey to Becoming an Air Force Cadet"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] Initializing feed: MSRC Security Update Guide | https://api.msrc.microsoft.com/update-guide/rss
# [+] INIT article "MSRC Security Update Guide - CVE-2021-31982 Microsoft Edge (Chromium-based) Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2021-34506 Microsoft Edge (Chromium-based) Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2021-34475 Microsoft Edge (Chromium-based) Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2021-42307 Microsoft Edge (Chromium-based) Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2022-29144 Microsoft Edge (Chromium-based) Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-28261 Microsoft Edge (Chromium-based) Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33140 Microsoft OneNote Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-24881 Microsoft Teams Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33151 Microsoft Outlook Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-38173 Microsoft Edge for Android Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35311 Microsoft Outlook Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35392 Microsoft Edge (Chromium-based) Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-38187 Microsoft Edge (Chromium-based) Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3727 Use after free in WebRTC"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3728 Use after free in WebRTC"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3730 Use after free in Tab Groups"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3732 Out of bounds memory access in Mojo"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3733 Inappropriate implementation in WebApp Installs"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3734 Inappropriate implementation in Picture In Picture"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3735 Inappropriate implementation in Web API Permission Prompts"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3736 Inappropriate implementation in Custom Tabs"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3737 Inappropriate implementation in Notifications"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3738 Inappropriate implementation in Autofill"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3740 Insufficient validation of untrusted input in Themes"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-21531 Azure Service Fabric Container Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2021-27075 Azure Virtual Machine Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-24932 Secure Boot Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33127 .NET and Visual Studio Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-24936 .NET, .NET Framework, and Visual Studio Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-36883 Microsoft Edge for iOS Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-36887 Microsoft Edge (Chromium-based) Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-36888 Microsoft Edge for Android (Chromium-based) Tampering Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-36884 Office and Windows HTML Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - ADV990001 Latest Servicing Stack Updates"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-21756 Windows Win32k Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33148 Microsoft Office Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33149 Microsoft Office Graphics Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33150 Microsoft Office Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33151 Microsoft Outlook Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33152 Microsoft ActiveX Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33153 Microsoft Outlook Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33165 Microsoft SharePoint Server Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33166 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33167 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33168 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33169 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33172 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33173 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33174 Windows Cryptographic Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32033 Microsoft Failover Cluster Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32034 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32035 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32037 Windows Layer-2 Bridge Network Driver Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32038 Microsoft ODBC Driver Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32039 Microsoft PostScript and PCL6 Class Printer Driver Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32040 Microsoft PostScript and PCL6 Class Printer Driver Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32041 Windows Update Orchestrator Service Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32042 OLE Automation Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32043 Windows Remote Desktop Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32044 Microsoft Message Queuing Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32045 Microsoft Message Queuing Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32046 Windows MSHTML Platform Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32047 Paint 3D Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - ADV230002 Microsoft Guidance for Addressing Security Feature Bypass in Trend Micro EFI Modules"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32049 Windows SmartScreen Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32050 Windows Installer Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32051 Raw Image Extension Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35313 Windows Online Certificate Status Protocol (OCSP) SnapIn Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35314 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35315 Windows Layer-2 Bridge Network Driver Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35316 Remote Procedure Call Runtime Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35317 Windows Server Update Service (WSUS) Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35318 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35319 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35320 Connected User Experiences and Telemetry Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35321 Windows Deployment Services Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35322 Windows Deployment Services Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35323 Windows OLE Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35324 Microsoft PostScript and PCL6 Class Printer Driver Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35325 Windows Print Spooler Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35326 Windows CDP User Components Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35328 Windows Transaction Manager Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35329 Windows Authentication Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35330 Windows Extended Negotiation Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35331 Windows Local Security Authority (LSA) Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35332 Windows Remote Desktop Protocol Security Feature Bypass"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35333 MediaWiki PandocUpload Extension Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35336 Windows MSHTML Platform Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35337 Win32k Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35338 Windows Peer Name Resolution Protocol Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35339 Windows CryptoAPI  Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35340 Windows CNG Key Isolation Service Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35341 Microsoft DirectMusic Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35342 Windows Image Acquisition Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35343 Windows Geolocation Service Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35344 Windows DNS Server Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35345 Windows DNS Server Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35346 Windows DNS Server Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35347 Microsoft Install Service Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35348 Active Directory Federation Service Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35350 Windows Active Directory Certificate Services (AD CS) Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35351 Windows Active Directory Certificate Services (AD CS) Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35352 Windows Remote Desktop Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35353 Connected User Experiences and Telemetry Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35356 Windows Kernel Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35357 Windows Kernel Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35358 Windows Kernel Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35360 Windows Kernel Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35361 Windows Kernel Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35362 Windows Clip Service Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35363 Windows Kernel Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35364 Windows Kernel Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35365 Windows Routing and Remote Access Service (RRAS) Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35366 Windows Routing and Remote Access Service (RRAS) Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35367 Windows Routing and Remote Access Service (RRAS) Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-36872 VP9 Video Extensions Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-36874 Windows Error Reporting Service Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-36884 Office and Windows HTML Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-21526 Windows Netlogon Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - ADV230001 Guidance on Microsoft Signed Drivers Being Used Maliciously"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-29347 Windows Admin Center Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33127 .NET and Visual Studio Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33134 Microsoft SharePoint Server Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33154 Windows Partition Management Driver Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33155 Windows Cloud Files Mini Filter Driver Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33156 Microsoft Defender Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33157 Microsoft SharePoint Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33158 Microsoft Excel Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33159 Microsoft SharePoint Server Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33160 Microsoft SharePoint Server Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33161 Microsoft Excel Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33162 Microsoft Excel Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33163 Windows Network Load Balancing Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33164 Remote Procedure Call Runtime Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33170 ASP.NET and Visual Studio Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33171 Microsoft Dynamics 365 (on-premises) Cross-site Scripting Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32052 Microsoft Power Apps (online) Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32053 Windows Installer Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32054 Volume Shadow Copy Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32055 Active Template Library Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32056 Windows Server Update Service (WSUS) Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32057 Microsoft Message Queuing Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32083 Microsoft Failover Cluster Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32084 HTTP.sys Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32085 Microsoft PostScript and PCL6 Class Printer Driver Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35296 Microsoft PostScript and PCL6 Class Printer Driver Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35297 Windows Pragmatic General Multicast (PGM) Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35298 HTTP.sys Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35299 Windows Common Log File System Driver Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35300 Remote Procedure Call Runtime Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35302 Microsoft PostScript and PCL6 Class Printer Driver Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35303 USB Audio Class System Driver Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35304 Windows Kernel Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35305 Windows Kernel Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35306 Microsoft PostScript and PCL6 Class Printer Driver Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35308 Windows MSHTML Platform Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35309 Microsoft Message Queuing Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35310 Windows DNS Server Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35311 Microsoft Outlook Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35312 Microsoft VOLSNAP.SYS Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35335 Microsoft Dynamics 365 (on-premises) Cross-site Scripting Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35373 Mono Authenticode Validation Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-35374 Paint 3D Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-36867 Visual Studio Code GitHub Pull Requests and Issues Extension Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-36868 Azure Service Fabric on Windows Information Disclosure Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-36871 Azure Active Directory Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-29356 Microsoft ODBC Driver for SQL Server Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32025 Microsoft ODBC Driver for SQL Server Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32026 Microsoft ODBC Driver for SQL Server Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32027 Microsoft ODBC Driver for SQL Server Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32028 Microsoft OLE DB Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-29349 Microsoft ODBC and OLE DB Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-24932 Secure Boot Security Feature Bypass Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2022-37967 Windows Kerberos Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2022-38023 Netlogon RPC Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-21808 .NET and Visual Studio Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2022-41089 .NET Framework Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-24897 .NET, .NET Framework, and Visual Studio Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-24895 .NET, .NET Framework, and Visual Studio Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-24936 .NET, .NET Framework, and Visual Studio Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-29331 .NET, .NET Framework, and Visual Studio Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-32032 .NET and Visual Studio Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33126 .NET and Visual Studio Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33128 .NET and Visual Studio Remote Code Execution Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3420 Type Confusion in V8"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3421 Use after free in Media"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3422 Use after free in Guest View"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-23383 Service Fabric Explorer Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-29357 Microsoft SharePoint Server Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33129 Microsoft SharePoint Denial of Service Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33130 Microsoft SharePoint Server Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33132 Microsoft SharePoint Server Spoofing Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - CVE-2023-33142 Microsoft SharePoint Server Elevation of Privilege Vulnerability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3214 Use after free in Autofill payments"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3215 Use after free in WebRTC"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "MSRC Security Update Guide - Chromium: CVE-2023-3216 Type Confusion in V8"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# ...
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - IOT Advisory Board Meeting"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Spotlight: Understanding Human-Tech Interactions With Computer Scientist Shanée Dawkins"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Digital Identity Guidelines Webinar (3): The Future of Authentication"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Digital Identity Guidelines Webinar (2): Innovating Identity Proofing"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Digital Identity Guidelines Webinar (1): Digital Identity Risk Management and Assurance Level Selection"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Cloud Computing Forensic Reference Architecture: NIST Requests Public Comments on SP 800-201"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Announcement of Proposal to Update NIST SP 800-38E, Using the XTS-AES Mode for Confidentiality on Storage Devices"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Lightweight Cryptography Standardization Process:  NIST Selects Ascon"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - 2023 Iris Experts Group (IEG) Meeting"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Selects ‘Lightweight Cryptography’ Algorithms to Protect Small Devices"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - High-Performance Computing (HPC) Security: Draft NIST SP 800-223 is Available for Public Comment"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Revises the Digital Signature Standard (DSS) and Publishes a Guideline for Elliptic Curve Domain Parameters"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Is Your Cybersecurity Strategy Falling Victim to These 6 Common Pitfalls?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Draft Call for Multi-Party Threshold Schemes: NIST IR 8214C ipd Available for Public Comment"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Releases Two Draft Guidelines on Personal Identity Verification (PIV) Credentials"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - An Introduction to Draft SP 800-157 Rev 1, Derived PIV Credentials and SP 800-217, PIV Federation"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Requests Public Comments on SP 800-132, Recommendation for Password-Based Key Derivation: Part 1: Storage Applications"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Digital Identity Guidelines - Kicking Off Revision 4!"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Applying the Cybersecurity Framework to Satellite Command and Control: NIST Interagency Report (IR) 8401"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - 9th Annual NICE K12 Cybersecurity Education Conference"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Announcement of Proposal to Update FIPS 197, The Advanced Encryption Standard"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Call for Comments on NIST Draft Revision 4 of SP 800-63: Digital Identity Guidelines"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Announcement of Proposal to Revise FIPS 180-4, Secure Hash Standard (SHS)"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Appoints Cherilyn Pascoe as New Director of the NCCoE"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - STPPA6: Special Topics on Privacy and Public Auditability — Event 6: Community Efforts on Advanced Cryptographic Techniques"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Getting Real – Smart Transportation in the City of Coral Gables, Florida"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST’s GCTC Paving Way for Electric Buses, Electric Truck Charging, and More"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST’s GCTC Leaders and Member Cities Participate in Smart City Workshop at the Western Hemisphere Cities Summit of the Americas"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - University, NIST Researchers Develop Strategy for Cutting Home HVAC Electricity Costs"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Making CPS Modeling Easier and Reusable – University, NIST Researchers Propose a Way"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST, University Researchers Develop Algorithm for Optimizing Large Network Performance"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Engineer Offers a Way to Realize the Digital Thread in Manufacturing"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Researcher Proposes Logistics Modeling for Complex Systems Design to OMG"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - OMG Approves NIST-aided Complex Systems Modeling Upgrade for Public Review"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - AI Can Accurately Predict Potentially Fatal Cardiac Events in Firefighters"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Spotlight: The Runaway Hit for Software Testing"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST-Designed Photonic Chip Transforms a Single Beam of Light Into Multiple Beams, Each With a Panoply of Different Properties"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - National Artificial Intelligence Advisory Committee Releases First Report"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Biden-Harris Administration Announces New NIST Public Working Group on AI"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - CHIPS for America: How to Complete a Full Application"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Top 5 at 5x5: What researchers won’t want to miss at the summit"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - South Korean Government Agencies, NIST Sign MOU to Cooperate on Automated Vehicle R&amp;D"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - 2nd International Workshop on FAIR Containerized Computational Software"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Top 5 at 5x5: Essential guide to public safety “don’t miss” sessions to boost your agency’s communications"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST 2022 Cybersecurity &amp; Privacy Annual Report"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Conducting Automated Vehicle Workshop, September 5-8, 2023"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - 6G “Mailbox Theory” by NIST, University Researchers Receives Best Paper Award"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST, Intel Researchers Win Best Paper at IEEE’s Factory Communications Systems Conference"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Staff Organize, Chair, and Present in Session on Industrial Wireless at IEEE Conference"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Creating and Reusing IoT Services – NIST, University Researchers Offer Solutions"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - University, NIST Researchers Develop Supply Chain Model Using NIST CPS Framework"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Researchers Demonstrate Improved Way of Training Distributed Digital Devices"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Leader Addresses Automated Vehicles’ Communications Needs at Conference"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Moving Toward Autonomous Systems – NIST Leader Offers Vision in University Presentation"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Leader Presents Quantum Network Testbed Connectivity Needs to Interagency Group"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST and Naval Research Laboratory Researchers Report on System for Managing Quantum Network Experiments"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - Workshop on OMB M-22-18 Minimum Requirements"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Revises SP 800-171 Guidelines for Protecting Sensitive Information"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - CHIPS for America: Overview of the Environmental Questionnaire"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - CHIPS for America Workforce Roundtable: Cross-Sector Partnerships"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Partners with NSF on New Institute for Trustworthy AI in Law &amp; Society (TRAILS)"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST’s SBIR Program Could be for You"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - CHIPS for America Outlines Vision for the National Semiconductor Technology Center"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] Initializing feed: Hacker News | https://hnrss.org/newest
# [+] INIT article "Hacker News - Thoughts on Analytics"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Date Me Directory"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Adtech is built on a privacy fault line"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - The Lunar Codex, a Time Capsule of Human Creativity, Stored in the Sky"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Cazenovia College Shutters After 200 Years, Exposing More Higher-Ed Distress"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - He Created the Katamari Games, but They’re Rolling on Without Him"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Ask HN: Are there any good T9 keyboards for Android?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - When the Wizards of the Web Met"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - It’s Time to Rethink Digital Ownership"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Salami Slicing Tactics"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Ask HN: What overlap is there between VP of Marketing and CTO/VP of Eng?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - 2023 Global Cloud Threat Cloud Attacks Are Fast"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Tell HN: Cannot Login to Heroku"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Alexithymia"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Gonew: Experimenting with Project Templates"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Judge Throws Out Lawsuit over Kraft Mac and Cheese Prep Time"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - World's First Hydrogen Train Will Be Replaced By Battery Trains After All"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Researchers figure out how to make AI misbehave, serve up prohibited content"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - ChatGPT-like AIs are coming to major science search engines"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Pricing Cheat Sheet for SaaS"
# 	[+] Getting article content...
# 	[+] Preprocessing content...

# %%
config = json.load(open('config/config.json'))
db_creds = json.load(open('config/' + config['db-creds-json-path']))

dbConn:RSS_DB_Connection = RSS_DB_Connection(
                                username=db_creds['username'],
                                password=db_creds['password'],
                                host=db_creds['host']
                            )

all_tags = dbConn.getAllTags()
all_articles = dbConn.getAllArticles()

# %% [markdown]
# #### Testing Gensim/LDA Clustering

# %%
lda:LDA_Article_Clustering = LDA_Article_Clustering(all_articles, num_topics=20, limit=1000)

# %%
s = lda.strAllTopicAssignments()
print(s)

# %%
s2 = ""
for i in range(len(lda.topics_dict.keys())):
    s2 += lda.strInfoForTopic(i)
    
print(s2)

# %% [markdown]
# ### Testing NER (Named Entity Recognition)

# %% [markdown]
# *NOTE: not effective*

# %%
# Load a pre-trained spacy model
nlp_model = spacy.load('en_core_web_sm')

article = all_articles[8]
article.__getArticleContent__()
tokens, content = article.__contentPreprocessing__(article.__getArticleContent__())

sample_article_text = content

#print(sample_article_text)

# Process the text 
doc = nlp_model(sample_article_text)

for entity in doc.ents: print("ENTITY: " + entity.text.replace(r'\n', '') + f" | LABEL: {entity.label_}")

# %% [markdown]
# ### Rule Based Tagging (keyword searching)

# %%
tag_names:list[str] = []

for t in all_tags: 
    if t.caseSensitive: tag_names.append(t.tagName)
    else: tag_names.append(t.tagName.lower())
    tag_names.append(t.tagName)

# %%
import re
def rule_based_tagging(text:str, tag_names:list[str]): 
    
    tagstr:str = "|".join(tag_names)
    tagPattern:re.Pattern = re.compile(r'\b(' + fr'{tagstr}' + r')\b')
    
    foundTags:list[str] = []
    
    if tagPattern.search(text): foundTags = tagPattern.findall(text)
    
    return list(set(foundTags))

# %%
for testArticle in bleepingComputerRss.articles:
    print(testArticle.toString())
    foundTags = rule_based_tagging(testArticle.preprocessed_content, tag_names)
    print(foundTags)
# Out:
# BleepingComputer: Amazon's AWS SSM agent can be used as post-exploitation RAT malware
# 		Link: https://www.bleepingcomputer.com/news/security/amazons-aws-ssm-agent-can-be-used-as-post-exploitation-rat-malware/
# 		Publish Date: 2023-08-02
# 		Description: Amazon's AWS SSM agent can be used as post-exploitation RAT malware
#
# ['north korean', 'breach']
# BleepingComputer: Why Every Security Practitioner Should Attend mWISE
# 		Link: https://www.bleepingcomputer.com/news/security/why-every-security-practitioner-should-attend-mwise/
# 		Publish Date: 2023-08-02
# 		Description: Why Every Security Practitioner Should Attend mWISE
#
# []
# BleepingComputer: Hackers exploited Salesforce zero-day in Facebook phishing attack
# 		Link: https://www.bleepingcomputer.com/news/security/hackers-exploited-salesforce-zero-day-in-facebook-phishing-attack/
# 		Publish Date: 2023-08-02
# 		Description: Hackers exploited Salesforce zero-day in Facebook phishing attack
#
# ['hacked']
# BleepingComputer: Hackers use new malware to breach air-gapped devices in Eastern Europe
# 		Link: https://www.bleepingcomputer.com/news/security/hackers-use-new-malware-to-breach-air-gapped-devices-in-eastern-europe/
# 		Publish Date: 2023-08-01
# 		Description: Hackers use new malware to breach air-gapped devices in Eastern Europe
#
# ['chinese', 'hacked']
# BleepingComputer: Threat actors abuse Google AMP for evasive phishing attacks
# 		Link: https://www.bleepingcomputer.com/news/security/threat-actors-abuse-google-amp-for-evasive-phishing-attacks/
# 		Publish Date: 2023-08-01
# 		Description: Threat actors abuse Google AMP for evasive phishing attacks
#
# []
# BleepingComputer: CISA issues new warning on actively exploited Ivanti MobileIron bugs
# 		Link: https://www.bleepingcomputer.com/news/security/cisa-issues-new-warning-on-actively-exploited-ivanti-mobileiron-bugs/
# 		Publish Date: 2023-08-01
# 		Description: CISA issues new warning on actively exploited Ivanti MobileIron bugs
#
# ['breach', 'zero day']
# BleepingComputer: Retail chain Hot Topic discloses wave of credential-stuffing attacks
# 		Link: https://www.bleepingcomputer.com/news/security/retail-chain-hot-topic-discloses-wave-of-credential-stuffing-attacks/
# 		Publish Date: 2023-08-01
# 		Description: Retail chain Hot Topic discloses wave of credential-stuffing attacks
#
# ['breach']
# BleepingComputer: Cybercriminals train AI chatbots for phishing, malware attacks
# 		Link: https://www.bleepingcomputer.com/news/security/cybercriminals-train-ai-chatbots-for-phishing-malware-attacks/
# 		Publish Date: 2023-08-01
# 		Description: Cybercriminals train AI chatbots for phishing, malware attacks
#
# ['lazarus', 'artificial intelligence']
# BleepingComputer: How to manage a mass password reset due to a ransomware attack
# 		Link: https://www.bleepingcomputer.com/news/security/how-to-manage-a-mass-password-reset-due-to-a-ransomware-attack/
# 		Publish Date: 2023-08-01
# 		Description: How to manage a mass password reset due to a ransomware attack
#
# []
# BleepingComputer: Hackers steal Signal, WhatsApp user data with fake Android chat app
# 		Link: https://www.bleepingcomputer.com/news/security/hackers-steal-signal-whatsapp-user-data-with-fake-android-chat-app/
# 		Publish Date: 2023-07-31
# 		Description: Hackers steal Signal, WhatsApp user data with fake Android chat app
#
# ['china']
# BleepingComputer: Google warns again it will start deleting inactive accounts in December
# 		Link: https://www.bleepingcomputer.com/news/google/google-warns-again-it-will-start-deleting-inactive-accounts-in-december/
# 		Publish Date: 2023-07-31
# 		Description: Google warns again it will start deleting inactive accounts in December
#
# []
# BleepingComputer: Canon warns of Wi-Fi security risks when discarding inkjet printers
# 		Link: https://www.bleepingcomputer.com/news/security/canon-warns-of-wi-fi-security-risks-when-discarding-inkjet-printers/
# 		Publish Date: 2023-07-31
# 		Description: Canon warns of Wi-Fi security risks when discarding inkjet printers
#
# []
