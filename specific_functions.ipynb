# %% [markdown]
# ## Description of Notebook

# %% [markdown]
# This notebook is designed to perform specific functions based on the cells you run. Each cell is labeled with its purpose and intent. This is intended to be  a simpler way to gather data from the database, make more specific queries, and search for more specific data - as opposed to the main script, which will simply collect all the articles from each RSS feed, preprocess them, and store them in the DB for future analysis.
#
# *Note that this notebook assumes there is a remote database set up and accessible*

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________
# ## Imports
#
# **RUN THIS CELL - needed for imports and initializing needed variables**

# %% [markdown]
# *What this cell does:*
#
# 1. Imports required libraries and custom classes
# 2. Initializes a Database connection
# 3. Initializes all the feeds
#     - Creates the RSS_Feed object (ex. BleepingComputerRSS, CensysRSS, etc)
#     - Gets all the new articles for the feeds
#     - Gets the content for these articles
#     - Preprocesses the content for these articles
# 4. Get a list of all tags from the Database

# %%
from data_analysis.ClusteringTechniques import *
from FP_Classes.RSS_DB_Connection import RSS_DB_Connection
import json 

from FP_Classes.RSS_Feed import RSS_Feed, RSS_Article
from FP_Classes.Tag import Tag
from FP_Classes.Feeds.BleepingComputer import BleepingComputerRSS   # BleepingComputer
from FP_Classes.Feeds.Censys import CensysRSS                       # Censys (general)
from FP_Classes.Feeds.CensysDir import CensysDirRSS                 # Censys (director)
from FP_Classes.Feeds.DefenseDepartment import DefenseDeptRSS       # Department of Defense
from FP_Classes.Feeds.Microsoft import MicrosoftRSS                 # Microsoft 
from FP_Classes.Feeds.NationalVulnDatabase import NVD_RSS           # National Vulnerability Database
from FP_Classes.Feeds.NIST import NIST_RSS                          # NIST 
from FP_Classes.Feeds.StateDepartment import StateDeptRSS           # State Department (multiple feeds) 
from FP_Classes.Feeds.TheHackerNews import HackerNewsRSS            # Hacker News (news articles)


config = json.load(open('config/config.json'))
db_creds = json.load(open('config/' + config['db-creds-json-path']))

dbConn:RSS_DB_Connection = RSS_DB_Connection(
                                username=db_creds['username'],
                                password=db_creds['password'],
                                host=db_creds['host']
                            )

# Initialization of all variables
configDir = "config/"   # Change ONLY if you changed the default file hierarchy 

# Update the remote DB with new tags if there are any
if dbConn.newTagsFromExcel(configDir + config['update-tags-filepath']):
    print("[+] NOTICE: Added new tags to remote database.")
else: print("[+] ERROR: Failed to add new tags to the remote database. Moving on.")

# Initialize all Feed objects 
bleepingComputerRss = BleepingComputerRSS(dbConn.getAllArticleTitles(feed_title=BleepingComputerRSS.BC_FeedTitle))
censysRss = CensysRSS(dbConn.getAllArticleTitles(feed_title=CensysRSS.CS_FeedTitle))
censysDirRss = CensysDirRSS(dbConn.getAllArticleTitles(feed_title=CensysDirRSS.CS_FeedTitle))
defenseDeptRss = DefenseDeptRSS(dbConn.getAllArticleTitles(feed_title=DefenseDeptRSS.DoD_FeedTitle))
microsoftRss = MicrosoftRSS(dbConn.getAllArticleTitles(feed_title=MicrosoftRSS.MS_FeedTitle))
nvdRss = NVD_RSS(dbConn.getAllArticleTitles(feed_title=NVD_RSS.NVD_FeedTitle))
nistRss = NIST_RSS(dbConn.getAllArticleTitles(feed_title=NIST_RSS.NIST_FeedTitle))
stateDeptRss = StateDeptRSS(dbConn.getAllArticleTitles(feed_title=StateDeptRSS.SD_FeedTitle)) 
hackernewsRss = HackerNewsRSS(dbConn.getAllArticleTitles(feed_title=HackerNewsRSS.HN_FeedTitle))

# Create a list of all the RSS Feed objects 
allFeeds:list[RSS_Feed] = [
    bleepingComputerRss,
    censysRss,
    censysDirRss,
    defenseDeptRss,
    microsoftRss,
    nvdRss,
    nistRss,
    stateDeptRss,
    hackernewsRss
]

allTags:list[Tag] = dbConn.getAllTags()
# Out:
# NOTICE in RSS_DB_Connection.newTagsFromExcel(): called newTagsFromExcel() - beginning process.
# NOTICE in RSS_DB_Connection.newTagsFromExcel(): excel sheet read and DB connection established successfully. Formatting query...
# NOTICE in RSS_DB_Connection.newTagsFromExcel(): new tag queries formatted and executed successfully. Terminating connections and quitting.
# SUCCESS.
# [+] NOTICE: Added new tags to remote database.
# [+] Initializing feed: BleepingComputer | https://www.bleepingcomputer.com/feed/
# [+] INIT article "BleepingComputer - Google to fight hackers with weekly Chrome security updates"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Preventative medicine for securing IoT tech in healthcare organizations"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - EvilProxy phishing campaign targets 120,000 Microsoft 365 users"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Microsoft Visual Studio Code flaw lets extensions steal passwords"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Microsoft Office update breaks actively exploited RCE attack chain"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Windows 11 KB5029263 cumulative update released with 27 fixes"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Microsoft August 2023 Patch Tuesday warns of 2 zero-days, 87 flaws"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Windows 10 KB5029244 and KB5029247 updates released"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Interpol takes down 16shop phishing-as-a-service platform"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - New Downfall attacks on Intel CPUs steal encryption keys, data"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - Android 14 to let you block connections to unencrypted cellular networks"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - New Inception attack leaks sensitive data from all AMD Zen CPUs"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "BleepingComputer - UK Electoral Commission data breach exposes 8 years of voter data"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] Initializing feed: Censys Global Reach | https://www.census.gov/content/census/en/newsroom/blogs/global-reach.xml
# [+] INIT article "Censys Global Reach - Exports Between the United States and Puerto Rico: When to File Electronic Export Information for Electronic Goods and Vehicles"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - License Code C64 — New Additions to the Automated Export System"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - New Commodity Classification Codes for the January 2022 Schedule B"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Data-Driven Business Decisions Begin Here"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Concordance Files: Data Users vs. Automated Export System (AES) Filers"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Avoiding Fatal Errors When Reporting the USPPI Address"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - How to Report Used Vehicles in AES"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Shipment Suppressed Email Confirmations"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Fancy Another Pint?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Monthly AES Compliance Reports: What Are They?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Exports Between the United States and Puerto Rico (Part 3)"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Exports Between the United States and Puerto Rico (Part 2)"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Exports Between the United States and Puerto Rico (Part 1)"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - How to Find Your Schedule B Number Revisited"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Holiday Food Trade Data 2019:  A Look Back at the Trade Patterns of Holiday Past"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - USPPI Address: Getting It Right in the Automated Export System"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Schedule B: Unit of Measure Changes"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - The ABCs of Mode of Transportation"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Is Thanksgiving Really Almost Here?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - ACE AESDirect Walkthrough Videos Available in English and Spanish"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - "Back to School, Back to Basics""
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - AES: Calculating Units of Measure"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Filing in AESDirect: How do you find your Internal Transaction Number?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - How to Choose the Correct Port of Export"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - The Automated Export System (AES) Compliance Review Program"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - "Roses and Chocolates and Bears, Oh My!""
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - 'Tis the Season of Holiday Shopping"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Submitting a Voluntary Self-Disclosure: Let�s Work Together!"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Wine or Beer?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - "Schedule B Codes, NAICS and NAPCS: The Similarities and Differences""
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - 2018 Customer Service Satisfaction Survey: We Value Your Feedback!"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach

# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - U.S. Trade with Japan in 2010"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - The United States – Canada Data Exchange"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - What is required for me to ship charity goods to Japan?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Proposed changes to the Foreign Trade Regulations"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Have You Used The Shipment Manager Yet?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Decoding the SRN"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Trade deficit increases to $46.3 billion in January"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Get Ready to Floss"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Are Your Rough Diamonds Kimberley Process Certified?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Featured Videos:  Registering and Filing a Shipment Using AESDirect"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - How to Write a (Simple) Export Plan"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - What is this? Leather?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Take Your Business Global"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - How Do You Report a Drop Shipment?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Understanding Basic DDTC License Requirements"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Shipments to Puerto Rico?"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - International Trade Shows are a Great Business Development Strategy"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Trade deficit decreases in October"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Connecting With You Virtually – Webinars"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Censys Global Reach - Dealing with Issues on a Standard Carrier Alpha Code (SCAC)"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# ...
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "National Vulnerability Database - CVE-2023-4219"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "National Vulnerability Database - CVE-2023-4239"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "National Vulnerability Database - CVE-2023-4242"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "National Vulnerability Database - CVE-2023-4243"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "National Vulnerability Database - CVE-2023-4273"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] Initializing feed: NIST Cybersecurity and IT news and events | https://www.nist.gov/pao/nist-rss-feeds
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Drafts Major Update to Its Widely Used Cybersecurity Framework"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Researchers Explore Best Practices for Talking to Kids About Online Privacy"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Drafts Major Update to Its Widely Used Cybersecurity Framework"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "NIST Cybersecurity and IT news and events - NIST Researchers Explore Best Practices for Talking to Kids About Online Privacy"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] Initializing feed: United States Department of State | https://www.state.gov/rss-feeds/
# 	Getting articles for link 1/6 | https://www.state.gov/rss-feed/counterterrorism/feed/
# [+] INIT article "United States Department of State - Designating Leaders and Financial Facilitators of ISIS and al-Qa’ida Cells in Maldives"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Eleventh Meeting of the Law Enforcement Coordination Group Focuses on Countering  Hizballah’s Global Terrorist, Financial, and Procurement Networks"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Joint Statement on the U.S.-EU Counterterrorism Dialogue"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Terrorist Designation of al-Shabaab Leaders"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - U.S. Welcomes Canada’s Repatriation from Northeast Syria"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Rewards for Justice – Reward Offer for Information on Ali Mohamed Rage"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Release of the 2021 Country Reports on Terrorism"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Acting Coordinator for Counterterrorism Landberg’s Travel to Qatar, Saudi Arabia"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 	Getting articles for link 2/6 | https://www.state.gov/rss-feed/europe-and-eurasia/feed/
# [+] INIT article "United States Department of State - Imposing Sanctions and Visa Restrictions to Hold the Lukashenka Regime to Account on the Third Anniversary of the Fraudulent Presidential Election in Belarus"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Secretary Blinken’s Call with Bulgarian Foreign Minister Gabriel"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Secretary Antony J. Blinken With Waihiga Mwaura of BBC Focus on Africa"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Secretary Blinken’s Call with Ukrainian Foreign Minister Kuleba"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Secretary Blinken’s Call with Republic of Cyprus Foreign Minister Kombos"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Marking Fifteen Years Since Russia’s Invasion and Occupation of Georgia"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Secretary Blinken’s Call with Turkish Foreign Minister Fidan"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Conviction and Sentencing of Aleksey Navalny on Additional Politically Motivated Charges"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - 79th Anniversary of Roma Murder at Auschwitz-Birkenau"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# 	Getting articles for link 3/6 | https://www.state.gov/rss-feed/east-asia-and-the-pacific/feed/
# [+] INIT article "United States Department of State - Singapore National Day"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Secretary Blinken’s Meeting with Indonesia’s Coordinating Minister for Investment and Maritime Affairs Luhut"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Acting Assistant Secretary Littlejohn’s Travel to Seattle for APEC SOM3"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Secretary Blinken’s Meeting with Indonesia’s Coordinating Minister for Investment and Maritime Affairs Luhut"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "United States Department of State - Secretary Blin

# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Housing costs making UK households much poorer than US peers"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Anonymize Your Website Upstream"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Fast, Cheap and Deadly"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - SponsorLink: Trying something new-ish for OSS sustainability"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Regulating Commercial Spyware [pdf]"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Climate change might trigger more earthquakes and volcanic eruptions"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - A New Weapon in the War on Robocall Scams"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Maui wildfires are 'apocalyptic' as people jump into the ocean to flee"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - DocFetcher"
# 	[+] Getting article content...
# 	[+] Preprocessing content...
#
# [+] INIT article "Hacker News - Birthday Paradox"
# 	[+] Getting article content...
# 	[+] Preprocessing content...

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________
# ## Interacting with the Database

# %% [markdown]
# ### [+] Get Information/Data from the Database

# %% [markdown]
# ##### Get a list of all tags (as Tag objects)

# %%
allTags:list[Tag] = dbConn.getAllTags()   # Get tags
for t in allTags: print(t.toString())     # Print results

# %% [markdown]
# ##### Get the titles for all tracked feeds

# %%
allFeedTitles:list[str] = dbConn.getAllFeeds()    # Get feed titles
for t in allFeedTitles: print(t)                  # Print the results

# %% [markdown]
# ##### Get lists of articles

# %% [markdown]
# *For a specific feed*

# %%
# Change feed title
feedTitle:str = "BleepingComputer"                          

allArticles:list[RSS_Article] = dbConn.getAllArticles(feedTitle=feedTitle) # Get all the articles
for a in allArticles: print(a.toString())                                  # Print the results

# %% [markdown]
# *No specific feed - all articles in DB (with SQL query limit, 1000 I think)*

# %%
allArticles:list[RSS_Article] = dbConn.getAllArticles()
for a in allArticles: print(a.toString())

# %% [markdown]
# *All articles for a list of tags*

# %%
# CHANGE list_of_tags !!
list_of_tags:list[str] = ['CVE', 'APT', 'Lazarus']      # List of strings (tag names) 

articles_for_tags:dict[str, RSS_Article] = dbConn.getArticlesForTags(list_of_tags)
for a in articles_for_tags.values(): print(a.toString(), a.tags)

# %% [markdown]
# ### [+] Sending new information to the Database

# %% [markdown]
# It is recommended to run both these cells. The first will only update the ARTICLES table, and the second will only update the TAGS_FOR_ARTICLE table. I kept them separate incase you only wish to do one or the other, but it is recommended to run both together.
#
# Also, the TAG_FOR_ARTICLE table in the database has a foreign key restraint on article_title, thus it is important to run the "Update Articles for RSS Feeds in Database" BEFORE running "Classify all New Articles and update tags in Database" because the INSERT statements into the TAG_FOR_ARTICLE table will fail if the article title does not exist in the ARTICLE table.

# %% [markdown]
# ##### Update Articles for RSS Feeds in Database

# %% [markdown]
# This cell will update the remote database with the new articles from the Import cell (cell 5). Note that this will not classify the articles, only add the Article object to the database "ARTICLE" table.

# %%
print("[+] Starting updates to database for all new articles...\n")

for feed in allFeeds: 
    if dbConn.addArticles(feed.articles): print(f"\tSuccessfully added articles for {feed.feed_title}.")
    else: print(f"\tThere was some error adding the articles for \"{feed.feed_title}\". Moving on.")

# Success message
print("\n[+] DONE: All articles were updated in the remote database.")
# Out:
# [+] Starting updates to database for all new articles...
#
# NOTICE: Articles added successfully.
# 	Successfully added articles for BleepingComputer.
# NOTICE: Articles added successfully.
# 	Successfully added articles for Censys Global Reach.
# NOTICE: Articles added successfully.
# 	Successfully added articles for Censys Director Blog.
# NOTICE: Articles added successfully.
# 	Successfully added articles for Defense-gov Explore Feed.
# NOTICE: Articles added successfully.
# 	Successfully added articles for MSRC Security Update Guide.
# NOTICE: Articles added successfully.
# 	Successfully added articles for National Vulnerability Database.
# NOTICE: Articles added successfully.
# 	Successfully added articles for NIST Cybersecurity and IT news and events.
# NOTICE: Articles added successfully.
# 	Successfully added articles for United States Department of State.
# NOTICE: Articles added successfully.
# 	Successfully added articles for Hacker News.
#
# [+] DONE: All articles were updated in the remote database.

# %% [markdown]
# ##### Classify All New Articles and update tags in Database

# %% [markdown]
# This will classify the new articles and send the tag updates to the database.

# %%
for feed in allFeeds: 
    if dbConn.updateArticles(feed, allTags): print(f"\n[+] Successfully classified and added articles for feed \"{feed.feed_title}\". Continuing...")
    else: print(f"\n[+] ERROR: There was some error classifying and updating articles for \"{feed.feed_title}\". Moving on...")
# Out:
# NOTICE in RSS_DB_Connection.__testFeedExists__(): test query found at least one result for "BleepingComputer". Proceeding.
# [+] Classifying and formatting queries for articles from feed: BleepingComputer
#
# [+] Updating database with articles for feed BleepingComputer
# [+] Updating database with tags for articles from feed: BleepingComputer
# NOTICE in RSS_DB_Connection.updateArticles(): new articles and tags for BleepingComputer added to the DB successfully. Closing cursor.
#
#
# [+] Successfully classified and added articles for feed "BleepingComputer". Continuing...
# NOTICE in RSS_DB_Connection.__testFeedExists__(): test query found at least one result for "Censys Global Reach". Proceeding.
# [+] Classifying and formatting queries for articles from feed: Censys Global Reach
#
# [+] Updating database with articles for feed Censys Global Reach
# [+] Updating database with tags for articles from feed: Censys Global Reach
# NOTICE in RSS_DB_Connection.updateArticles(): new articles and tags for Censys Global Reach added to the DB successfully. Closing cursor.
#
#
# [+] Successfully classified and added articles for feed "Censys Global Reach". Continuing...
# NOTICE in RSS_DB_Connection.__testFeedExists__(): test query found at least one result for "Censys Director Blog". Proceeding.
# [+] Classifying and formatting queries for articles from feed: Censys Director Blog
#
# [+] Updating database with articles for feed Censys Director Blog
# [+] Updating database with tags for articles from feed: Censys Director Blog
# NOTICE in RSS_DB_Connection.updateArticles(): new articles and tags for Censys Director Blog added to the DB successfully. Closing cursor.
#
#
# [+] Successfully classified and added articles for feed "Censys Director Blog". Continuing...
# NOTICE in RSS_DB_Connection.__testFeedExists__(): test query found at least one result for "Defense-gov Explore Feed". Proceeding.
# [+] Classifying and formatting queries for articles from feed: Defense-gov Explore Feed
#
# [+] Updating database with articles for feed Defense-gov Explore Feed
# [+] Updating database with tags for articles from feed: Defense-gov Explore Feed
# NOTICE in RSS_DB_Connection.updateArticles(): new articles and tags for Defense-gov Explore Feed added to the DB successfully. Closing cursor.
#
#
# [+] Successfully classified and added articles for feed "Defense-gov Explore Feed". Continuing...
# NOTICE in RSS_DB_Connection.__testFeedExists__(): test query found at least one result for "MSRC Security Update Guide". Proceeding.
# [+] Classifying and formatting queries for articles from feed: MSRC Security Update Guide
# NOTICE: Feed "MSRC Security Update Guide does not have any articles of interest. Exiting.
#
# [+] Successfully classified and added articles for feed "MSRC Security Update Guide". Continuing...
# NOTICE in RSS_DB_Connection.__testFeedExists__(): test query found at least one result for "National Vulnerability Database". Proceeding.
# [+] Classifying and formatting queries for articles from feed: National Vulnerability Database
#
# [+] Updating database with articles for feed National Vulnerability Database
# [+] Updating database with tags for articles from feed: National Vulnerability Database
# NOTICE in RSS_DB_Connection.updateArticles(): new articles and tags for National Vulnerability Database added to the DB successfully. Closing cursor.
#
#
# [+] Successfully classified and added articles for feed "National Vulnerability Database". Continuing...
# NOTICE in RSS_DB_Connection.__testFeedExists__(): test query found at least one result for "NIST Cybersecurity and IT news and events". Proceeding.
# [+] Classifying and formatting queries for articles from feed: NIST Cybersecurity and IT news and events
# NOTICE: Feed "NIST Cybersecurity and IT news and events does not have any articles of interest. Exiting.
#
# [+] Successfully classified and added articles for feed "NIST Cybersecurity and IT news and events". Continuing...
# NOTICE in RSS_DB_Connection.__testFeedExists__(): test query found at least one result for "United States Department of State". Proceeding.
# [+] Classifying and formatting queries for articles from feed: United States Department of State
#
# [+] Updating database with articles for feed United States Department of State
# [+] Updating database with tags for articles from feed: United States Department of State
# NOTICE in RSS_DB_Connection.updateArticles(): new articles and tags for United States Department of State added to the DB successfully. Closing cursor.
#
#
# [+] Successfully classified and added articles for feed "United States Department of State". Continuing...
# NOTICE in RSS_DB_Connection.__testFeedExists__(): test query found at least one result for "Hacker News". Proceeding.
# [+] Classifying and formatting queries for articles from feed: Hacker News
# NOTICE: Feed "Hacker News does not have any articles of interest. Exiting.
#
# [+] Successfully classified and added articles for feed "Hacker News". Continuing...

# %% [markdown]
# __________________________________________________________________________________________________________________________________________________________________________
# ## Latent Dirichlet Allocation (LDA) Analysis

# %% [markdown]
# **Purpose:**
# LDA is a natural language processing technique that aims to group (cluster) related articles together based on their content and the importance of common words and phrases (in context of the overall article).
#
# **NOTE:**
# Run the hyperparameters cell before any others or they will not work.

# %% [markdown]
# #### [+] LDA Hyperparameters
#
# **RUN THIS CELL**
#
# *Note: this cell may take a few minutes, depending on how many articles are returned and the lda_LIMIT*

# %%
''' 
lda_NUM_TOPICS - The number of clusters in the final result
    
    NOTE: A higher num_topics can be beneficial but may take longer.
          Too high of a value for num_topics could overfit the data and result in irrelevant topics or clusters 
          Too low of a value for num_topics could underfit the data and result in clusters that are hard to interpret

lda_LIMIT - The limit on the number of articles to get from the DB.

    NOTE: A higher limit will take longer, but will include more articles and the groupings will likely be more meaningful.
          A limit of 0 -> no limit, get all articles in the DB

lda_FEED - Specify a specific feed to get articles from (the feed title).

    NOTE: Make sure the feed exists in the DB. If you are not sure, see the "Feeds" section to get a list of all feed titles from the DB
          Empty string ("") -> no specific feed, get articles for all feeds
          
'''

lda_NUM_TOPICS:int  = 10
lda_LIMIT:int       = 100
lda_FEED:str        = ""

# --------------------------------------------------------------------------------------------------------- #
# DO NOT CHANGE BELOW THIS LINE

# Get other parameters based on the above hyperparameters
lda_articles:list[RSS_Article] = dbConn.getAllArticles(feedTitle=lda_FEED)
lda:LDA_Article_Clustering = LDA_Article_Clustering(lda_articles, num_topics=lda_NUM_TOPICS, limit=lda_LIMIT)

# %% [markdown]
# #### [+] Print LDA Results

# %%
print("\n---------------------------\nLDA Topic Assignments:\n" + lda.strAllTopicAssignments())

s = "" 
for i in range(len(lda.topics_dict.keys())): s += lda.strInfoForTopic(i)
print("\n---------------------------\nLDA Topic Details and Articles:\n\n" + s)
